# %%
try:
    import nbformat
    import traceback
    print("A biblioteca 'nbformat' já está instalada. Pulando instalação.\n")
except ImportError:
    print("Biblioteca 'nbformat' não encontrada. Instalando...\n")
    # %pip install -q nbformat
    print("Instalação concuída com sucesso!\n")

# %run scripts\converter_md_para_ipynb.py
# Out:
# A biblioteca 'nbformat' já está instalada. Pulando instalação.
#
# Atualizado: fichamento_ReliableBenchmarkingRequirementsSolutions_Beyer.ipynb
# Sucesso! 1 novos notebooks foram gerados.
